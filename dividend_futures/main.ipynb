# %%
import div_app
import bql

# %%
bq = bql.Service()

# %%
app = div_app.DividendApp(bq)

# %%
app
# Out:
# DividendApp(children=(VBox(children=(Accordion(children=(HTML(value='\n        <div style ="color:ivory; backg…
